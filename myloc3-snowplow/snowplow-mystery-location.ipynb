# %%
import overpass
import geopandas
import matplotlib.pyplot as plt
import folium
import geojson

def bbox_to_bounds(bbox):
    bo = bbox.split(", ")
    bounds = [[bo[0], bo[3]], [bo[2], bo[1]]]

    return bounds

def overpass_this(element, key, value = None):
    if value != None:
        q = '{}["{}"="{}"]({})'.format(element,key, value, bbox)
    else:
        q = '{}["{}"]({})'.format(element,key,bbox)
    resp = api.Get(q)
    name = "{element}-{key}-{value}.geojson".format(element=element, key=key, value=value)
    open(name, "w").write(str(resp))
    return geopandas.read_file(name)

def new_map(style='cartodbpositron'):
    m = folium.Map(tiles=style)
    m.fit_bounds(bounds)
    return m

def dump(data, mapview = None):
    if mapview == None:
        mapview = new_map()
    points = folium.features.GeoJson(geojson.dumps(data))
    mapview.add_children(points)
    return mapview

from IPython.display import HTML
def street_views(locations, height = 250):
    html_code = ''
    for location in locations:
        html_code = html_code + """
<iframe style="width:100%;height:{height}px;"
frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
src="http://my.ctrlq.org/maps/#street|0.01|0|0|{y_coord}|{x_coord}">
</iframe>""".format(
           x_coord = location.centroid.x,
           y_coord = location.centroid.y,
           height = height
        )
    return HTML(html_code)

def earth_view(locations, height=400, zoom= 19):
    html_code= ''
    for location in locations:
        html_code = """<iframe
        style="width: 100%; height: {height}px;" frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
        src="http://my.ctrlq.org/maps/#hybrid|{zoom}|{y_coord}|{x_coord}"></iframe>
        """.format(
           x_coord = location.centroid.x,
           y_coord = location.centroid.y,
           height = height,
           zoom=zoom,
        )
    return HTML(html_code)

import tempfile
def to_GeoSeries(geojson):
    temp = tempfile.mktemp(prefix="tmp_geo_", suffix=".geojson")
    open(temp, "w").write(str(geojson))
    return geopandas.read_file(temp)
    

bbox = "59.30516, 10.55511, 59.47508, 10.83115"
bounds = bbox_to_bounds(bbox)
api = overpass.API()

# %% [markdown]
# # Initialize bounding box and API for Moss

# %%
bbox = "59.30516, 10.55511, 59.47508, 10.83115"
bounds = bbox_to_bounds(bbox)
api = overpass.API()

# %%
b = overpass_this("way", "bridge")
t = overpass_this("way", "tunnel")
m = new_map(style='Stamen Terrain')
dump(b, m)
dump(t, m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# # Open A streetmap view
#
# This is not from any particular place. but it is nice to have the streetview in nteract, since it performs better than a browser, and saves from context-switching.

# %%
earth_view()
# Out:
# <iframe
#     style="width: 100%; height: 500px;" frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
#     src="http://my.ctrlq.org/maps/#hybrid|21|40.70233311051662|-74.00882313126546"></iframe>

# %%
r = overpass_this("way", "junction", "roundabout")
n = new_map("OpenStreetMap")
r = r.buffer(0.001)
dump(r,n)
dump(t,n)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# # Tunnels that are near roundabouts

# %%
intersection = r.unary_union.intersection(t.unary_union) 
dump(intersection)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
street_views(intersection)
# Out:
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.409155850000005|10.694489149999999">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.42284300803832|10.692665095469268">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.433232450000006|10.660393500000001">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.44536065|10.70356535">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.433356399999994|10.6618358">
# </iframe>

# %% [markdown]
# # Brute forcing through roundabouts
#
# None of the ones near tunnel where the correct ones, so we spread the serach.

# %%
street_views(r)
# Out:
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.42366625812898|10.6671734599463">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.419434523014246|10.682094085501392">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.446234948798306|10.685611496770699">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.44541776082603|10.699869415937695">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.46304824725819|10.688215972267182">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.41671499932941|10.685733645309746">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.43381747095384|10.653433714568187">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.43312181839023|10.660918056661794">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.434432964263465|10.670231139293218">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.445359606922324|10.704262478899008">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.44552223335333|10.706423344658077">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.38559707285334|10.750755916901626">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.43364877208781|10.649803922177417">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.42356187552821|10.69318111227385">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.37893088994236|10.752650205075842">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.435154408178505|10.604035510451046">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.44004975362632|10.710580010873459">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.41316649320704|10.688596991520473">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.37041718300233|10.783980477353216">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.38627848190834|10.752160710547654">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.45787620399626|10.695255740843509">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.42210164327725|10.67614456389902">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.40856915838166|10.695206506216076">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.43325396077746|10.66090272895013">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.433185534765634|10.661087827632965">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.423496805750034|10.693365294929567">
# </iframe>
# <iframe style="width:100%;height:250px;"
# frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
# src="http://my.ctrlq.org/maps/#street|0.01|0|0|59.41652880930827|10.680606680097464">
# </iframe>

# %% [markdown]
# # Lets look for hill
#
# There is a topology dataset, but let's first see what openstreetmap has to offer.

# %%
h = overpass_this("node", "natural", "peak")
r = overpass_this("way", "junction", "roundabout")
r.buffer(0.001)
n = new_map()
dump(h,n)
dump(r,n)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
h
# Out:
#       description:no  ele                       geometry         name natural
# 0  Moss kommunetopp.  140  POINT (10.6355352 59.4549791)  Rambergåsen    peak

# %%
earth_view(h.geometry)
# Out:
# <iframe
#         style="width: 100%; height: 400px;" frameborder="0" scrolling="no" marginheight="0" marginwidth="0"
#         src="http://my.ctrlq.org/maps/#hybrid|19|59.4549791|10.6355352"></iframe>

# %% [markdown]
# # Moving to Troms
#
# The buildings look rather more typical for northern Norway, and there are now hills like the one in the background in Moss.
#
# Let's start by lookuin up the most obvious things, the roundabouts.

# %%
bbox= "69.6191, 18.80104, 69.72358, 19.09836"
bounds = bbox_to_bounds(bbox)

# %%
tr = overpass_this("way", "junction", "roundabout")
tr = tr.buffer(0.005)
tr = tr.unary_union
trcs = geopandas.GeoSeries([poly.centroid for poly in tr])
tm = new_map()
dump(trcs,tm)
dump(tr, tm)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# # A narrower filter
#
# The idea was to narrow the seach area by removing elements that are not on the east side of a `"natural"="peak"`. However, it seems that the hills in Tromsø do not fill the Norwegian criteria for a peak :smile:

# %%
tr = overpass_this("way", "junction", "roundabout")
tt = overpass_this("way", "tunnel")

road_types = ["pedestrian", "footway"]
tsr = api.Get(
    """(
    way["highway"="footway"]({bbox});
    way["highway"="pedestrian"]({bbox})
)
    """.format(bbox = bbox))
tb = api.Get('way["bridge"]({})'.format(bbox))
# this qery returns data that will not be ofx use
#tp = overpass_this("node", "natural", "peak")
tmap = new_map("Stamen Terrain")
tr = tr.to_crs({'proj': "utm +zone=33 +ellps=WGS84 +datum=WGS84 +units=m +no_defs"})
tr = tr.buffer(100)
tr = tr.to_crs({'init' :'epsg:4326'}) 
dump(tr, tmap)
dump(tsr, tmap)
#dump(tsr, tmap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
print(type(tr))
print(type(tsr))
tsrGs = to_GeoSeries(tsr)
print(type(tsrGs))
# Out:
# <class 'shapely.geometry.multipolygon.MultiPolygon'>
# <class 'geojson.feature.FeatureCollection'>
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
tsrGsU = tsrGs.unary_union
pois = tru.intersection(tsrGsU)
print(type(pois))
m = new_map()
dump(pois,m)
dump(tru,m)
# Out:
# <class 'shapely.geometry.multilinestring.MultiLineString'>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# # Mapillary photo keys
#
#
# - red backside of round street mirror: kvlvqd7cUvDPi5xosLgoVQ
# - yellow building in on street level in the background: Y6AzuKhr7qZ1K2WuOA33CA
#
# ![](https://d1cuyjsrcm0gby.cloudfront.net/kvlvqd7cUvDPi5xosLgoVQ/thumb-2048.jpg)
# ![](https://d1cuyjsrcm0gby.cloudfront.net/Y6AzuKhr7qZ1K2WuOA33CA/thumb-2048.jpg)

# %%
tr = overpass_this("way", "junction", "roundabout")
tsr = api.Get(
    """(
    way["highway"="footway"]({bbox});
    way["highway"="pedestrian"]({bbox})
    )
    """.format(bbox = bbox))

# roundtrip to utm33 for buffering
tr = tr.to_crs({'proj': "utm +zone=33 +ellps=WGS84 +datum=WGS84 +units=m +no_defs"})
tr = tr.buffer(100)
tr = tr.to_crs({'init' :'epsg:4326'})
# ROIs in dataset intersections
tru = tr.unary_union
tsrGs = to_GeoSeries(tsr)
rois = tru.intersection(tsrGs.unary_union)


# query returns useless data
#tp = overpass_this("node", "natural", "peak")
tmap = new_map("Cartodb dark_matter")
dump(rois,tmap)
dump(tru,tmap)
tmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
